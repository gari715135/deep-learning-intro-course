# %% [markdown]
# # Import data and display sample

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data(
    path='mnist.npz'
)
print(f"train_imgs shape:\t{train_images.shape}\ntest_imgs shape:\t{test_images.shape}")

def plot_digit(image_data):
    image = image_data.reshape(28, 28)
    plt.imshow(image, cmap="binary")
    plt.axis("off")

plt.figure(figsize=(3, 3))
for idx, image_data in enumerate(train_images[:25]):
    plt.subplot(5, 5, idx + 1)
    plot_digit(image_data)
plt.subplots_adjust(wspace=0, hspace=0)
plt.show()
# Out:
# train_imgs shape:	(60000, 28, 28)
# test_imgs shape:	(10000, 28, 28)

# %% [markdown]
# # Sample NN

# %%
from tensorflow import keras
from tensorflow.keras import layers
